# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("../../dataset/L3_data_int_initial.pkl", "rb") as f:
    L3_dic = pickle.load(f)
print(L3_dic)
# Out:
# {('277', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 0.916, 'mean_volume': 37.50426392769299, 'deviation_of_volume': 7.233975083186754, 'sigmoid': {'a': -0.21136913847545463, 'b': 6.546141197740096, 'c': -0.45060255599457955}}, ('298', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 0.9560000000000001, 'mean_volume': 42.204793244176216, 'deviation_of_volume': 7.2058990766443785, 'sigmoid': {'a': 0.4902902330350596, 'b': 0.5510546331196284, 'c': 0.2619210236533768}}, ('308', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 0.9800000000000001, 'mean_volume': 54.58893086219415, 'deviation_of_volume': 7.21198452138557, 'sigmoid': {'a': 0.21969549147961148, 'b': 0.5419156537268304, 'c': 0.2772117436347421}}, ('318', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 0.9880000000000001, 'mean_volume': 73.98031318136688, 'deviation_of_volume': 7.237032765088001, 'sigmoid': {'a': 0.04229988629973327, 'b': 0.48504619206232746, 'c': 0.7094192794129094}}, ('328', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 0.9960000000000001, 'mean_volume': 74.18904068191047, 'deviation_of_volume': 7.223313791951765, 'sigmoid': {'a': 3.265178627693058e-13, 'b': -0.18476082012249445, 'c': 1.2419869889345494}}, ('338', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 1.0, 'mean_volume': 80.90497159954438, 'deviation_of_volume': 7.211102550927977, 'sigmoid': {'a': 2.554573519287711e-55, 'b': 0.5999999795168551, 'c': 0.9999999746163191}}, ('348', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 0.9960000000000001, 'mean_volume': 83.57644021987929, 'deviation_of_volume': 7.206852734755398, 'sigmoid': {'a': 0.0, 'b': 0.0, 'c': 1.0}}, ('358', 'home/user/SA-EDS/int_initial/L3_initial_0'): {'ratio_of_volume': 1.0, 'mean_volume': 84.75432763217457, 'deviation_of_volume': 7.211102550927977, 'sigmoid': {'a': 0.0, 'b': 0.0, 'c': 1.0}}, ('277', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 0.8266666666666668, 'mean_volume': 70.55088078845634, 'deviation_of_volume': 8.785062286490689, 'sigmoid': {'a': 1.0225358104559028, 'b': 0.8329664729698922, 'c': 0.3662161081826816}}, ('298', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 0.9533333333333335, 'mean_volume': 46.61380002287115, 'deviation_of_volume': 8.656666690343307, 'sigmoid': {'a': 0.5867326202524703, 'b': 0.7628081341175876, 'c': 0.2895144276805778}}, ('308', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 0.9533333333333335, 'mean_volume': 52.77156916582926, 'deviation_of_volume': 8.765374593611478, 'sigmoid': {'a': 0.588552418773531, 'b': 0.6793400894676944, 'c': 0.38542037575460425}}, ('318', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 0.9700000000000001, 'mean_volume': 65.83573201288638, 'deviation_of_volume': 8.738595875788471, 'sigmoid': {'a': 0.10960171095629759, 'b': 0.4935852055035297, 'c': 0.3620109426310034}}, ('328', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 0.99, 'mean_volume': 74.9301266933237, 'deviation_of_volume': 8.653682422446234, 'sigmoid': {'a': 0.03648885990707452, 'b': 2.7931237923861145, 'c': 0.888233030450398}}, ('338', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 0.9933333333333334, 'mean_volume': 81.02265017602052, 'deviation_of_volume': 8.665288869443648, 'sigmoid': {'a': 0.022273659726409045, 'b': 1.0614951308340266, 'c': 3.241136008631751}}, ('348', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 1.0, 'mean_volume': 83.00628942991266, 'deviation_of_volume': 8.65544144839919, 'sigmoid': {'a': 0.0, 'b': 0.0, 'c': 1.0}}, ('358', 'home/user/SA-EDS/int_initial/L3_initial_1'): {'ratio_of_volume': 1.0, 'mean_volume': 87.37109393501865, 'deviation_of_volume': 8.65544144839919, 'sigmoid': {'a': 0.0, 'b': 0.0, 'c': 1.0}}, ('277', 'home/user/SA-EDS/int_initial/L3_initial_2'): {'ratio_of_volume': 0.8920000000000001, 'mean_volume': ...

# %%
def plot_relation(dic, target_x, target_y, temp):
    x = []
    y = []
    for key in dic:
        # print(key[0])
        if key[0] == temp:
            if target_x == "sigmoid":
                x.append(dic[key][target_x]["a"]/dic[key][target_x]["c"])
            else:
                x.append(dic[key][target_x])
            if target_y == "sigmoid":
                y.append(dic[key][target_y]["a"]/dic[key][target_y]["c"])
            else:
                y.append(dic[key][target_y])

        # プロットを作成
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, 'o', markersize=5, label=f'{target_y} vs {target_x}')
    plt.xlabel(target_x)
    plt.ylabel(target_y)
    plt.title(f'Relation between {target_x} and {target_y}')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_relation(L3_dic, "ratio_of_volume", "sigmoid", "277")
plot_relation(L3_dic, "mean_volume", "sigmoid", "277")

# %%
def func(x, a, b, c):
    return a /(np.exp(-b * x) + c)

# %%
def plot_funcs(params_list, x_range=(0, 10), num_points=1000):
    x = np.linspace(x_range[0], x_range[1], num_points)
    
    plt.figure(figsize=(10, 6))
    for params in params_list:
        a, b, c = params
        y = func(x, a, b, c)
        # plt.plot(x, y, label=f'a={a}, b={b}, c={c}, b/c={b/c}, (a/c)*b = {(a/c)*b}, b/(a/c) = {b/(a/c)}')
        plt.plot(x, y, label=f'a={a}, b={b}, c={c}, b = {b}, a/c={a/c}')
    
    plt.xlabel('x')
    plt.ylabel('func(x)')
    plt.title('Plot of func(x, a, b, c)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Example usage
plot_funcs([(2, 1, 1), (2, 1, 2), (2, 2, 1), (2, 1, 0.5)])

# %%
plot_funcs([(1, 1, 1), (1, 2, 1)]) # bはスピード

# %%
plot_funcs([(1, 1, 2), (1, 1, 1)]) # cが大きいほど最終値は小さい

# %%
plot_funcs([(1, 1, 1), (2, 1, 1)]) # aが大きいほど最終値は大きい
